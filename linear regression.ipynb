# %% [markdown]
# What is regression model
#
# Regression algorithms,
#
# Model Evaluation Techniques,
#
# Overfitting and Underfitting

# %% [markdown]
# Regression: It is a way to predict a number . It helps us find out how one thing changes when something else changes.

# %% [markdown]
# Gradient Descent ka jab curve banna hota hai tab Repeat convergence Theorem ka used krte hai.
# Learning Rate ko less rkte hai kyuki loss function ke value  jadda alag alag n ho with the help of this finally we go down and reached at global minima

# %% [markdown]
# ![image.png](attachment:bf898880-1a6a-4eb7-a0dc-bcb7881b3095.png)

# %% [markdown]
# overfitting - low bias(training) perform good, high variance(testing) perform bad
#
# underfiiting - high bias(training) perform bad, high varaiance(trsting) perform bad

# %% [markdown]
# So for perfect model we need low bias and low variance

# %% [markdown]
# so for making perfect model we have to understand Ridge and Lasso Regression , This regression help us to overcome from overfitting and underfitting
